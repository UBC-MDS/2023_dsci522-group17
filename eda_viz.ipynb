# %%
from hashlib import sha1
import numpy as np
import pandas as pd

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)


df = pd.read_csv("fifa_2022_datasets/players_22.csv", encoding="utf-8", low_memory=False)
train_df, test_df = train_test_split(df, test_size=0.3, random_state=123)
train_df
# Out:
#        sofifa_id                                         player_url  \
# 6505      190471  https://sofifa.com/player/190471/bernard-parke...
# 13949     248216  https://sofifa.com/player/248216/thomas-hasal/...
# 10813     253129  https://sofifa.com/player/253129/gaston-comas/...
# 1493      175895  https://sofifa.com/player/175895/vadis-odjidja...
# 4874      213490  https://sofifa.com/player/213490/izzy-brown/22...
# ...          ...                                                ...
# 13435     192811  https://sofifa.com/player/192811/jack-payne/22...
# 7763      211047  https://sofifa.com/player/211047/jorge-salinas...
# 15377     242149  https://sofifa.com/player/242149/kevin-kouassi...
# 17730     262921  https://sofifa.com/player/262921/alexander-baz...
# 15725     259466  https://sofifa.com/player/259466/thijs-jansen/...
#
#                   short_name                      long_name player_positions  \
# 6505               B. Parker                 Bernard Parker      CF, CAM, LW
# 13949               T. Hasal                   Thomas Hasal               GK
# 10813               G. Comas             Jorge Gastón Comas               CM
# 1493         V. Odjidja-Ofoe             Vadis Odjidja-Ofoe     CM, CDM, CAM
# 4874                I. Brown                   Isaiah Brown          CAM, CM
# ...                      ...                            ...              ...
# 13435               J. Payne             Jack Stephen Payne          CM, CDM
# 7763              J. Salinas  Jorge Martín Salinas Martínez      CAM, LM, RM
# 15377  K. Kouassivi-Benissan       Kevin Kouassivi-Benissan           RB, RW
# 17730       A. Bazdrigiannis        Alexander Bazdrigiannis               RM
# 15725              T. Jansen                   Thijs Jansen               GK
#
#        overall  potential  value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# 6505        68         68   525000.0     500.0   35  ...  44+2  44+2  44+2
# 13949       62         73   775000.0     750.0   21  ...  21+2  21+2  21+2
# 10813       65         72  1400000.0    3000.0   23  ...  59+2  59+2  59+2
# 1493        75         75  4400000.0   22000.0   32  ...  71+2  71+2  71+2
# 4874        70         75  2400000.0   16000.0   24  ...  52+2  52+2  52+2
# ...        ...        ...        ...       ...  ...  ...   ...   ...   ...
# 13435       62         62   400000.0    3000.0   29  ...  60+2  60+2  60+2
# 7763        67         67  1000000.0     500.0   29  ...  50+2  50+2  50+2
# 15377       60         70   525000.0     500.0   22  ...  54+2  54+2  54+2
# 17730       56         69   350000.0     500.0   19  ...  31+2  31+2  31+2
# 15725       60         74   500000.0     550.0   19  ...  22+2  22+2  22+2
#
#          rb    gk                                    player_face_url  \
# 6505   50+2  19+2  https://cdn.sofifa.net/players/190/471/22_120.png
# 13949  19+2  61+2  https://cdn.sofifa.net/players/248/216/22_120.png
# 10813  61+2  15+2  https://cdn.sofifa.net/players/253/129/22_120.png
# 1493   70+2  18+2  https://cdn.sofifa.net/players/175/895/22_120.png
# 4874   56+2  15+2  https://cdn.sofifa.net/players/213/490/22_120.png
# ...     ...   ...                                                ...
# 13435  61+1  18+2  https://cdn.sofifa.net/players/192/811/22_120.png
# 7763   56+2  15+2  https://cdn.sofifa.net/players/211/047/22_120.png
# 15377  58+2  16+2  https://cdn.sofifa.net/players/242/149/22_120.png
# 17730  39+2  15+2  https://cdn.sofifa.net/players/262/921/22_120.png
# 15725  22+2  59+2  https://cdn.sofifa.net/players/259/466/22_120.png
#
#                                     club_logo_url  \
# 6505   https://cdn.sofifa.net/teams/110929/60.png
# 13949  https://cdn.sofifa.net/teams/101112/60.png
# 10813  https://cdn.sofifa.net/teams/111716/60.png
# 1493      https://cdn.sofifa.net/teams/674/60.png
# 4874     https://cdn.sofifa.net/teams/1801/60.png
# ...                                           ...
# 13435  https://cdn.sofifa.net/teams/110890/60.png
# 7763   https://cdn.sofifa.net/teams/114688/60.png
# 15377  https://cdn.sofifa.net/teams/100325/60.png
# 17730  https://cdn.sofifa.net/teams/110691/60.png
# 15725     https://cdn.sofifa.net/teams/246/60.png
#
#                                  club_flag_url  nation_logo_url  \
# 6505       https://cdn.sofifa.net/flags/za.png              NaN
# 13949      https://cdn.sofifa.net/flags/us.png              NaN
# 10813      https://cdn.sofifa.net/flags/ar.png              NaN
# 1493       https://cdn.sofifa.net/flags/be.png              NaN
# 4874   https://cdn.sofifa.net/flags/gb-eng.png              NaN
# ...                                        ...              ...
# 13435  https://cdn.sofifa.net/flags/gb-eng.png              NaN
# 7763       https://cdn.sofifa.net/flags/py.png              NaN
# 15377      https://cdn.sofifa.net/flags/fi.png              NaN
# 17730      https://cdn.sofifa.net/flags/de.png              NaN
# 15725      https://cdn.sofifa.net/flags/nl.png              NaN
#
#                                nation_flag_url
# 6505       https://cdn.sofifa.net/flags/za.png
# 13949      https://cdn.sofifa.net/flags/ca.png
# 10813      https://cdn.sofifa.net/flags/ar.png
# 1493       https://cdn.sofifa.net/flags/be.png
# 4874   https://cdn.sofifa.net/flags/gb-eng.png
# ...                                        ...
# 13435  https://cdn.sofifa.net/flags/gb-eng.png
# 7763       https://cdn.sofifa.net/flags/py.png
# 15377      https://cdn.sofifa.net/flags/fi.png
# 17730      https://cdn.sofifa.net/flags/de.png
# 15725      https://cdn.sofifa.net/flags/nl.png
#
# [13467 rows x 110 columns]

# %%
import altair as alt
alt.data_transformers.enable("vegafusion")

df_numeric = df.select_dtypes(include = ['int64', 'float64'])
df_numeric_list = df_numeric.columns
print(df_numeric_list)
# initialize an empty list to store the distribution of each numeric column
charts_numeric = []

# create a visualization of the distribution of each numeric column and store it in the `charts` list
for column in df_numeric_list:
    chart = alt.Chart(df).mark_bar().encode(
        alt.X(column, bin=alt.Bin(maxbins=20), title=f'{column}'),
        alt.Y('count()', title='Frequency')
    ).properties(
        width=150,
        height=100,
        title=f'Distribution of {column}'
    )
    charts_numeric.append(chart)
length = len(charts_numeric)
# Create a 4x4 grid with all the distributions
alt.vconcat(
    alt.hconcat(*charts_numeric[:round(length/4)]),
    alt.hconcat(*charts_numeric[round(length/4):round(length/2)]),
    alt.hconcat(*charts_numeric[round(length/2):round(3*length/4)]),
    alt.hconcat(*charts_numeric[round(3*length/4):length-1])
).configure_title(fontSize=10).configure_axis(titleFontSize=8)

# alt.vconcat(
#     alt.hconcat(*charts_numeric[:4]),
#     alt.hconcat(*charts_numeric[4:8]),
#     alt.hconcat(*charts_numeric[8:12]),
#     alt.hconcat(*charts_numeric[12:16])
# ).configure_title(fontSize=10).configure_axis(titleFontSize=8)
# Out:
# Index(['sofifa_id', 'overall', 'potential', 'value_eur', 'wage_eur', 'age',
#        'height_cm', 'weight_kg', 'club_team_id', 'league_level',
#        'club_jersey_number', 'club_contract_valid_until', 'nationality_id',
#        'nation_team_id', 'nation_jersey_number', 'weak_foot', 'skill_moves',
#        'international_reputation', 'release_clause_eur', 'pace', 'shooting',
#        'passing', 'dribbling', 'defending', 'physic', 'attacking_crossing',
#        'attacking_finishing', 'attacking_heading_accuracy',
#        'attacking_short_passing', 'attacking_volleys', 'skill_dribbling',
#        'skill_curve', 'skill_fk_accuracy', 'skill_long_passing',
#        'skill_ball_control', 'movement_acceleration', 'movement_sprint_speed',
#        'movement_agility', 'movement_reactions', 'movement_balance',
#        'power_shot_power', 'power_jumping', 'power_stamina', 'power_strength',
#        'power_long_shots', 'mentality_aggression', 'mentality_interceptions',
#        'mentality_positioning', 'mentality_vision', 'mentality_penalties',
#        'mentality_composure', 'defending_marking_awareness',
#        'defending_standing_tackle', 'defending_sliding_tackle',
#        'goalkeeping_diving', 'goalkeeping_handling', 'goalkeeping_kicking',
#        'goalkeeping_positioning', 'goalkeeping_reflexes', 'goalkeeping_speed'],
#       dtype='object')
